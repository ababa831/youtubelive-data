# %% [markdown]
# # Youtube配信のコメントデータを拾うテスト

# %% [markdown]
# **下記リンクを参考に、必要なクラス、メソッド等を簡単に纏めたメモ**
# - https://github.com/shughes-uk/python-youtubechat/blob/master/youtubechat/ytchat.py
# - https://starhoshi.hatenablog.com/entry/2018/01/07/015121
#
# (old)
# - https://blog.sky-net.pw/article/86
# - https://github.com/youtube/api-samples/blob/master/python/list_broadcasts.py

# %% [markdown]
# ## 注意
# - 他人の放送からコメントデータを拾う場合は、`LiveBloadcast: list`で`ChatID`を拾うことはできない。[参考](https://stackoverflow.com/questions/34688099/how-do-i-use-livebroadcastslist-from-youtube-api)
#     - 代わりに、`Videos: list ->  VideoID ->  LiveChatMessages: list -> activeChatID`というフェーズで取得するしか無い。
#
#
# - 放送中のデータは、最新コメントから遡って最大75件しか取得できない。(公式では最大2000件とあるが、実際は75件に制限されている)

# %% [markdown]
# ## 準備

# %%
# This Python file uses the following encoding: utf-8

import cgi
import logging
import sys
import threading
import time
from datetime import datetime, timedelta
from json import dumps, loads
from pprint import pformat

import dateutil.parser
import httplib2
from oauth2client import client
from oauth2client.file import Storage

import webbrowser


PY3 = sys.version_info[0] == 3
if PY3:
    from urllib.parse import urlencode
    from queue import Queue
else:
    from Queue import Queue
    from urllib import urlencode

# %%
def _json_request(http, url, method='GET', headers=None, body=None):
    resp, content = http.request(url, method, headers=headers, body=body)
    content_type, content_type_params = cgi.parse_header(resp.get('content-type', 'application/json; charset=UTF-8'))
    charset = content_type_params.get('charset', 'UTF-8')
    data = loads(content.decode(charset))
    if 'error' in data:
        error = data['error']
        raise YoutubeLiveChatError(error['message'], error.get('code'), error.get('errors'))
    return resp, data

# %%
class LiveChatApi(object):
    
    def __init__(self, http):
        """
        代入するhttpは、以下の手順で拾う
        1. storage = Storage(credential_file)
        2. credentials = storage.get()
        3. http = credentials.authorize(httplib2.Http())
        """
        self.http = http
        self.logger = logging.getLogger("liveChat_api")
        
        
    def get_live_chat_id(self, video_id):
        url = "https://www.googleapis.com/youtube/v3/videos?"
        params = {'part': 'liveStreamingDetails','id': video_id}
        params = urlencode(params)
        response_obj, video_data = _json_request(self.http, url + params)
        livechatId = video_data['items'][0]['liveStreamingDetails']['activeLiveChatId']
        return livechatId
        

    def get_all_messages(self, livechatId):
        data = self.live_chat_messages_list(livechatId, maxResults=2000)
        total_items = data['pageInfo']['totalResults']
        pageToken = data['nextPageToken']
        if len(data['items']) < total_items:
            time.sleep(data['pollingIntervalMillis'] / 1000)
            while len(data['items']) < total_items:
                other_data = self.live_chat_messages_list(livechatId, maxResults=2000, pageToken=pageToken)
                if not other_data['items']:
                    break
                else:
                    data['items'].extend(other_data['items'])
                    pageToken = other_data['nextPageToken']
                    time.sleep(other_data['pollingIntervalMillis'] / 1000)
        return data

    def live_chat_messages_list(self,
                                livechatId,
                                part='snippet,authorDetails',
                                maxResults=200,
                                pageToken=None,
                                profileImageSize=None):
        url = 'https://www.googleapis.com/youtube/v3/liveChat/messages'
        url = url + '?liveChatId={0}'.format(livechatId)
        if pageToken:
            url = url + '&pageToken={0}'.format(pageToken)
        if profileImageSize:
            url = url + '&profileImageSize={0}'.format(profileImageSize)
        url = url + '&part={0}'.format(part)
        url = url + '&maxResults={0}'.format(maxResults)
        resp, data = _json_request(self.http, url)
        return data

# %% [markdown]
# ## 認証

# %%
if not hasattr(__builtins__,'raw_input'):
    # Python 3
    raw_input = input
flow = client.flow_from_clientsecrets(
    'client_secrets.json',
    scope=['https://www.googleapis.com/auth/youtube', 'https://www.googleapis.com/auth/youtube.force-ssl'],
    redirect_uri='urn:ietf:wg:oauth:2.0:oob')
auth_uri = flow.step1_get_authorize_url()
webbrowser.open(auth_uri)
auth_code = raw_input("auth code: ") # Sコードを貼り付ける
credentials = flow.step2_exchange(auth_code)
http_auth = credentials.authorize(httplib2.Http())
storage = Storage("oauth_creds")
storage.put(credentials)

# %% [markdown]
# ## コメントデータ取得

# %%
# Initial settings
credential_file = "oauth_creds"
storage = Storage(credential_file)
credentials = storage.get()
http = credentials.authorize(httplib2.Http())

# Getting live streaming all chat data
livechat = LiveChatApi(http)
video_id = "7ja9BBrqbJg"
chat_id = livechat.get_live_chat_id(video_id)
chat_data = livechat.get_all_messages(chat_id)

# %%
chat_data
# Out:
# {'kind': 'youtube#liveChatMessageListResponse',
#  'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/OWq99JlhK41I2wmpVVUooZQjv4Y"',
#  'nextPageToken': 'GM3FpLvel9wCIK6467Tfl9wC',
#  'pollingIntervalMillis': 30000,
#  'offlineAt': '2018-07-11T19:03:51.000Z',
#  'pageInfo': {'totalResults': 75, 'resultsPerPage': 75},
#  'items': [{'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/8LBQv66EqyflltPq3gR5Jh_d8Ag"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ0lteHV0SE5sOXdDRlVrTFpBb2Q4MklKYlESHENMM1EzY1hObDl3Q0ZRdnNXQW9kbUg4SFpBLTA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UC5NtcWICb8ggcWVDi5ZieeQ',
#     'publishedAt': '2018-07-11T17:48:20.202Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)お久しぶりという名のこんにちわ',
#     'textMessageDetails': {'messageText': '音量(0)お久しぶりという名のこんにちわ'}},
#    'authorDetails': {'channelId': 'UC5NtcWICb8ggcWVDi5ZieeQ',
#     'channelUrl': 'http://www.youtube.com/channel/UC5NtcWICb8ggcWVDi5ZieeQ',
#     'displayName': '魄畏蓮久',
#     'profileImageUrl': 'https://yt3.ggpht.com/-iaV5WzngUks/AAAAAAAAAAI/AAAAAAAAAAA/tPHy87C9-0Y/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/FA052H74uJrpt7ReqzrGG1x1ZfE"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ0tQMTJPYk5sOXdDRlkwNlpBb2Q4Rm9IcGcSHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTE0',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T17:49:04.743Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)蓮久さん、こんばんは〜',
#     'textMessageDetails': {'messageText': '音量(0)蓮久さん、こんばんは〜'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/eSxWwM5fv4LgizexfdxXVc9sntY"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ01icC1fUE5sOXdDRlVzTWhBb2RocDBNY3cSHENOV08wSjdIbDl3Q0ZRMzZXQW9kTElJRFNRLTc',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T17:49:32.577Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)やさかさんﾚｽﾄさんこんばんわ',
#     'textMessageDetails': {'messageText': '音量(0)やさかさんﾚｽﾄさんこんばんわ'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/EX-s0SrMedQ93Py9y2u4KTBc-f0"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOQoaQ1Bqc25ZM09sOXdDRlFRR2hBb2RsRElKVXcSG0NQLWE0X0RNbDl3Q0ZjY1dLZ29kWGNFT0pRMg',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCGuNu9nVsSBx0S2D2fLgnLQ',
#     'publishedAt': '2018-07-11T17:50:25.564Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)割と起きてるんだなw',
#     'textMessageDetails': {'messageText': '音量(0)割と起きてるんだなw'}},
#    'authorDetails': {'channelId': 'UCGuNu9nVsSBx0S2D2fLgnLQ',
#     'channelUrl': 'http://www.youtube.com/channel/UCGuNu9nVsSBx0S2D2fLgnLQ',
#     'displayName': 'yasaka Frn',
#     'profileImageUrl': 'https://yt3.ggpht.com/-C2aT8BVrSbM/AAAAAAAAAAI/AAAAAAAAAAA/sA7dcvC9ajc/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/ljWunZdBO9JUhyMeC3qCCbrbO54"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ002RmxZN09sOXdDRlpBWVpBb2RUekFNVVESJ0NLS25pb1hPbDl3Q0ZlZ2ZXQW9kMGwwRmdRMTUzMTMzMTQyNjUyOQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'publishedAt': '2018-07-11T17:50:27.517Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)まだやってた',
#     'textMessageDetails': {'messageText': '音量(0)まだやってた'}},
#    'authorDetails': {'channelId': 'UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'channelUrl': 'http://www.youtube.com/channel/UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'displayName': '鮭38号',
#     'profileImageUrl': 'https://yt3.ggpht.com/-vuxOMF1aQeQ/AAAAAAAAAAI/AAAAAAAAAAA/9TV8piiuiiY/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/RMzwKG7RTWasVdcI_T98cQXcddM"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ05HNnE1bk9sOXdDRlVVdlpBb2RTeEFJYlESHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTE1',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T17:50:50.953Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)鮭さん、こんばんは〜',
#     'textMessageDetails': {'messageText': '音量(0)鮭さん、こんばんは〜'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/avat_VdoGdOc3sjMgXvawq0mDn0"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOQoaQ091b29LRE9sOXdDRmMxMm1Bb2RTYXNGclESG0NPeXh0NEhPbDl3Q0ZkRTFLZ29kTXVNRXRBMA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UC5NtcWICb8ggcWVDi5ZieeQ',
#     'publishedAt': '2018-07-11T17:51:05.450Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)烏でエイトロってきつくね？さっき思ったけど',
#     'textMessageDetails': {'messageText': '音量(0)烏でエイトロってきつくね？さっき思ったけど'}},
#    'authorDetails': {'channelId': 'UC5NtcWICb8ggcWVDi5ZieeQ',
#     'channelUrl': 'http://www.youtube.com/channel/UC5NtcWICb8ggcWVDi5ZieeQ',
#     'displayName': '魄畏蓮久',
#     'profileImageUrl': 'https://yt3.ggpht.com/-iaV5WzngUks/AAAAAAAAAAI/AAAAAAAAAAA/tPHy87C9-0Y/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/T4nqqTMlQZ5TyXUuJZrAhcopjLI"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ01iRmlLTE9sOXdDRmNsV21Bb2RKdEVFa0ESJ0NPR0swUERObDl3Q0ZRMmxXQW9kNWtrUF9BMTUzMTMzMTQ2ODkxMQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T17:51:09.255Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)おはよーございます(；・∀・)💧',
#     'textMessageDetails': {'messageText': '音量(0)おはよーございます(；・∀・)💧'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/zg59NqkmgXJ6zyUzyYMXPpqhImA"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ0wtcmxiRE9sOXdDRlpBVGhBb2RCc3dEWUESHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTE2',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T17:51:38.825Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)ぺぇさん、おはよ〜',
#     'textMessageDetails': {'messageText': '音量(0)ぺぇさん、おはよ〜'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/EFSST7e6i9HYw-6E1AfBRua61xk"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ09uVTdiak9sOXdDRlVjSVpBb2ROWUlLWUESHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTE3',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T17:51:57.049Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)寝落ち？',
#     'textMessageDetails': {'messageText': '音量(0)寝落ち？'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/imVrahe_pQBt_GJfnawYKOB_HC4"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ1B5NXByX09sOXdDRlk1Um1Bb2RBc3dKWkESHENOV08wSjdIbDl3Q0ZRMzZXQW9kTElJRFNRLTg',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T17:52:10.562Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)ぺぇさんグッモーニン…(･∀･)',
#     'textMessageDetails': {'messageText': '音量(0)ぺぇさんグッモーニン…(･∀･)'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY
z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)ぺぇさん起きてて大丈夫ですか…?(・_・;)',
#     'textMessageDetails': {'messageText': '音量(0)ぺぇさん起きてて大丈夫ですか…?(・_・;)'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/oCUG0b-bnDHNqugvXEmrimXi8H8"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ09HUTNyN1hsOXdDRlZGbG1Bb2R1LThMZUESJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzMzk0NTY0Mg',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T18:32:25.296Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)大丈夫ですよ～( *´꒳`* )むしろ寝たので寝れないという()',
#     'textMessageDetails': {'messageText': '音量(0)大丈夫ですよ～( *´꒳`* )むしろ寝たので寝れないという()'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/TeKVUwoyU1hStd1JYSFkguHQgHc"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ0p6ZHp0clhsOXdDRmRKem1Bb2RrbWtJLXcSHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTI3',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T18:33:23.764Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)21時に寝て起きたら、寝れないですよね〜()',
#     'textMessageDetails': {'messageText': '音量(0)21時に寝て起きたら、寝れないですよね〜()'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/9CgHwYWq8RamYntawuWtJSbKWG8"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ0o3QnNmVFhsOXdDRlRGem1Bb2RhUHdNdEESHUNOV08wSjdIbDl3Q0ZRMzZXQW9kTElJRFNRLTIw',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T18:34:17.812Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)なら大丈夫…かな? 眠くなったらすぐ寝てくださいね｀‐ω‐´)',
#     'textMessageDetails': {'messageText': '音量(0)なら大丈夫…かな? 眠くなったらすぐ寝てくださいね｀‐ω‐´)'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/kK8BAiIzbLfzMLMYvg57xlvKoMw"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ09QVjVKM1lsOXdDRlF3S1pBb2RfQndLSWcSJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzNDE0NDk3NA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T18:35:44.633Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)みそさんジンレイさんご心配ありがとうです(*^^*)そのうちまた寝落ちすると思います💦',
#     'textMessageDetails': {'messageText': '音量(0)みそさんジンレイさんご心配ありがとうです(*^^*)そのうちまた寝落ちすると思います💦'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/blbJkmvVpU7gQoup_orizI2cIjQ"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ1Buc3Z1ellsOXdDRllReVpBb2Q1UW9NLVESHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTI4',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T18:38:29.688Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)まぁ寝れない内は、配信みたいですよね？、わかりますw',
#     'textMessageDetails': {'messageText': '音量(0)まぁ寝れない内は、配信みたいですよね？、わかりますw'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/xt7n8CLff2Z-eurUtTNqg5o2HEI"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ0xqZzdmN1lsOXdDRlVsOW1Bb2R6eVFEREESJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzNDM0ODU0NQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T18:39:08.206Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)Ye( •∀• )s!!',
#     'textMessageDetails': {'messageText': '音量(0)Ye( •∀• )s!!'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/XnHBSaynrU8ek_RyUBriqJVjEH0"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOwoaQ1AzQy1welpsOXdDRlkwNlpBb2RwcVFJZUESHUNPdmttdkNfbDl3Q0ZVUUlLZ29kNG5jRFFnLTI5',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T18:40:11.329Z',
#     'hasDisplayContent': True,
#     'displayMessage': '一期一会チャンプは大変だw',
#     'textMessageDetails': {'messageText': '一期一会チャンプは大変だw'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/Q-scal36ZuRaKc-JwZqvBfWIqTg"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ09TYXd1dlpsOXdDRll4Wm1Bb2Q0T29CdWcSHENQR212YjNabDl3Q0ZTY1ZXQW9kZmRNT0NBLTA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCs6Rd57U2AjfV4Gv-OAskWw',
#     'publishedAt': '2018-07-11T18:42:56.082Z',
#     'hasDisplayContent': True,
#     'displayMessage': '音量(0)ウルトの精度案の定で草も生えない',
#     'textMessageDetails': {'messageText': '音量(0)ウルトの精度案の定で草も生えない'}},
#    'authorDetails': {'channelId': 'UCs6Rd57U2AjfV4Gv-OAskWw',
#     'channelUrl': 'http://www.youtube.com/channel/UCs6Rd57U2AjfV4Gv-OAskWw',
#     'displayName': 'Quart',
#     'profileImageUrl': 'https://yt3.ggpht.com/-i4LQPMw2fLM/AAAAAAAAAAI/AAAAAAAAAAA/tuesc5zHPoM/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY
',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'publishedAt': '2018-07-11T18:55:44.128Z',
#     'hasDisplayContent': True,
#     'displayMessage': '女性型の殺人機械なら一部に需要ありそう',
#     'textMessageDetails': {'messageText': '女性型の殺人機械なら一部に需要ありそう'}},
#    'authorDetails': {'channelId': 'UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'channelUrl': 'http://www.youtube.com/channel/UCbLJ9wuK5uE2h7KOrLuQKMg',
#     'displayName': '鮭38号',
#     'profileImageUrl': 'https://yt3.ggpht.com/-vuxOMF1aQeQ/AAAAAAAAAAI/AAAAAAAAAAA/9TV8piiuiiY/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/WYAykfvTCGRj1uK-etMaq-CWhQ8"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ1AzcG5lN2NsOXdDRllkNm1Bb2RtMkVKM3cSHENJSEN1ZUxjbDl3Q0ZRRzRXQW9kSjV3SERnLTA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T18:56:27.084Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'え？もうしてないっけ',
#     'textMessageDetails': {'messageText': 'え？もうしてないっけ'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/yFnyvjxfyH9Bae7qt6PHSfRfU2E"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ0pmMGhKN2RsOXdDRllndFpBb2QwVmtETncSHENKREV4WlhkbDl3Q0ZjMFZXQW9kZWJVQ0t3LTA',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T18:58:07.339Z',
#     'hasDisplayContent': True,
#     'displayMessage': '確かにアニメ化しますね',
#     'textMessageDetails': {'messageText': '確かにアニメ化しますね'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/tHmYnz88IOaNu3p1g1swO0NMrpc"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ01Lb3ByYmRsOXdDRllsUG1Bb2RkbFFOVVESHENJSEN1ZUxjbDl3Q0ZRRzRXQW9kSjV3SERnLTE',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T18:58:58.218Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'midﾁｬﾝﾌﾟ少なめですね',
#     'textMessageDetails': {'messageText': 'midﾁｬﾝﾌﾟ少なめですね'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/uUKF-b7Bi2ZuhzvWnjGlHlcJ_PU"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ1BmRXhzUGRsOXdDRmNOZG1Bb2RuZkVJMEESHENKREV4WlhkbDl3Q0ZjMFZXQW9kZWJVQ0t3LTE',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T18:59:26.008Z',
#     'hasDisplayContent': True,
#     'displayMessage': '何があったんだ？',
#     'textMessageDetails': {'messageText': '何があったんだ？'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/CFCe4bVkfNm52-zIQbRUZVRAKk0"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ09heXJlTGRsOXdDRlFzeVpBb2RyWEFHTFESHENKREV4WlhkbDl3Q0ZjMFZXQW9kZWJVQ0t3LTI',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T19:00:30.608Z',
#     'hasDisplayContent': True,
#     'displayMessage': '一方的ウィンw',
#     'textMessageDetails': {'messageText': '一方的ウィンw'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/ESQruOcy5oK-21F2ZD967EuQ5yA"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ0kyS3dfcmRsOXdDRlpKc21Bb2RPY2dIeWcSHENKREV4WlhkbDl3Q0ZjMFZXQW9kZWJVQ0t3LTM',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T19:01:21.295Z',
#     'hasDisplayContent': True,
#     'displayMessage': '相互利益があれば良い',
#     'textMessageDetails': {'messageText': '相互利益があれば良い'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/fBcjz2riedUOySfzR1CwNUEIzKY"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ095MzhvRGVsOXdDRlZKZm1Bb2R4cGdGSUESJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzNTY5NDk3Nw',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T19:01:34.654Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'ﾖｼﾞｰ',
#     'textMessageDetails': {'messageText': 'ﾖｼﾞｰ'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/Q2qGXjynkmNobi-sWgWsSPALHn4"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ09IdDdMTGVsOXdDRlExb21Bb2ROa01LSVESHENKREV4WlhkbDl3Q0ZjMFZXQW9kZWJVQ0t3LTQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'publishedAt': '2018-07-11T19:03:19.420Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'しゅーやさん、皆々様、お疲れ様です、おやすみなさい',
#     'textMessageDetails': {'messageText': 'しゅーやさん、皆々様、お疲れ様です、おやすみなさい'}},
#    'authorDetails': {'channelId': 'UCMc8-C8S_9rYLrTvHrey9kA',
#     'channelUrl': 'http://www.youtube.com/channel/UCMc8-C8S_9rYLrTvHrey9kA',
#     'displayName': 'ジンレイ000',
#     'profileImageUrl': 'https://yt3.ggpht.com/-yqVwlbEcUtk/AAAAAAAAAAI/AAAAAAAAAAA/5ObPAtBCGXE/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/17xql4ewl90BqT9N6ORS9FODGGQ"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ055dmtMWGVsOXdDRmFvSWhBb2RXQmtQQmcSJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzNTgwNDUxOQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T19:03:24.196Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'お疲れ様でしたヾ(｡･v･｡)',
#     'textMessageDetails': {'messageText': 'お疲れ様でしたヾ(｡･v･｡)'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/11-FehEwLvrW3BMa92DikMDdk8c"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ0x1NnVyYmVsOXdDRlVZelpBb2RzcW9DWncSHENJSEN1ZUxjbDl3Q0ZRRzRXQW9kSjV3SERnLTI',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T19:03:26.983Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'お疲れ様でした〜',
#     'textMessageDetails': {'messageText': 'お疲れ様でした〜'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/y8MOuSCSH0WGtWAFoEYk7Pyt_0Y"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSRQoaQ1BxVHRycmVsOXdDRlVzcVpBb2RqYWdIQ3cSJ0NQaWktTFRPbDl3Q0ZWQWJXQW9kd0JRSlVRMTUzMTMzNTgxNTYzMQ',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'publishedAt': '2018-07-11T19:03:35.301Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'おやすみなさい♪',
#     'textMessageDetails': {'messageText': 'おやすみなさい♪'}},
#    'authorDetails': {'channelId': 'UCWlNSNcLthyouTRN3Ox5c5w',
#     'channelUrl': 'http://www.youtube.com/channel/UCWlNSNcLthyouTRN3Ox5c5w',
#     'displayName': 'あやぺぇ21',
#     'profileImageUrl': 'https://yt3.ggpht.com/-v5UpHb8wZSg/AAAAAAAAAAI/AAAAAAAAAAA/rEchjpVMGXo/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}},
#   {'kind': 'youtube#liveChatMessage',
#    'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/jtSVSeqPLpALcmqynRYJckPG8m8"',
#    'id': 'LCC.Cg8KDQoLN2phOUJCcnFiSmcSOgoaQ00zRnBMdmVsOXdDRmNaTm1Bb2RjZVFHREESHENJSEN1ZUxjbDl3Q0ZRRzRXQW9kSjV3SERnLTM',
#    'snippet': {'type': 'textMessageEvent',
#     'liveChatId': 'Cg0KCzdqYTlCQnJxYkpn',
#     'authorChannelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'publishedAt': '2018-07-11T19:03:37.110Z',
#     'hasDisplayContent': True,
#     'displayMessage': 'おやすみー',
#     'textMessageDetails': {'messageText': 'おやすみー'}},
#    'authorDetails': {'channelId': 'UCe8vGY3esaCjRggkvHaOLHw',
#     'channelUrl': 'http://www.youtube.com/channel/UCe8vGY3esaCjRggkvHaOLHw',
#     'displayName': 'みそずっぺ',
#     'profileImageUrl': 'https://yt3.ggpht.com/-Gn7-g_0aeRA/AAAAAAAAAAI/AAAAAAAAAAA/xEE8D2KQoV4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'isVerified': False,
#     'isChatOwner': False,
#     'isChatSponsor': False,
#     'isChatModerator': False}}]}
